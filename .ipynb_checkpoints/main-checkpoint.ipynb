# %%
import pandas as pd
import numpy as np

file_path = "/home/nguyen.the.toan/Documents/other_projects/breast-cancer/data.csv"
data = pd.read_csv(file_path, delimiter=",", header=None, skipinitialspace=True)
data.head()
# Out:
#          0          1            2             3               4          5   \
# 0        id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 1    842302          M        17.99         10.38           122.8       1001
# 2    842517          M        20.57         17.77           132.9       1326
# 3  84300903          M        19.69         21.25             130       1203
# 4  84348301          M        11.42         20.38           77.58      386.1
#
#                 6                 7               8                    9  ...  \
# 0  smoothness_mean  compactness_mean  concavity_mean  concave points_mean ...
# 1           0.1184            0.2776          0.3001               0.1471 ...
# 2          0.08474           0.07864          0.0869              0.07017 ...
# 3           0.1096            0.1599          0.1974               0.1279 ...
# 4           0.1425            0.2839          0.2414               0.1052 ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 33 columns):
# 0     570 non-null object
# 1     570 non-null object
# 2     570 non-null object
# 3     570 non-null object
# 4     570 non-null object
# 5     570 non-null object
# 6     570 non-null object
# 7     570 non-null object
# 8     570 non-null object
# 9     570 non-null object
# 10    570 non-null object
# 11    570 non-null object
# 12    570 non-null object
# 13    570 non-null object
# 14    570 non-null object
# 15    570 non-null object
# 16    570 non-null object
# 17    570 non-null object
# 18    570 non-null object
# 19    570 non-null object
# 20    570 non-null object
# 21    570 non-null object
# 22    570 non-null object
# 23    570 non-null object
# 24    570 non-null object
# 25    570 non-null object
# 26    570 non-null object
# 27    570 non-null object
# 28    570 non-null object
# 29    570 non-null object
# 30    570 non-null object
# ...
